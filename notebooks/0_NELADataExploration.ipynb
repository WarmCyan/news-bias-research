# %%
# %load_ext autoreload
# %autoreload 2

# %%
import util
import pandas as pd

# %% [markdown]
# # Label Exploration

# %%
labels_df = util.nela_load_labels()
print(labels_df.shape[0], " article sources", "\n", labels_df.shape[1], " gt source labels")
# Out:
# 194  article sources
#  58  gt source labels

# %%
util.GT_COLS.keys()
# Out:
# dict_keys(['NewsGuard', 'Pew Research Center', 'Wikipedia', 'Open Sources', 'Media Bias / Fact Check', 'Allsides', 'BuzzFeed', 'Politifact'])

# %% [markdown]
# # The Values of All

# %%
for column in labels_df.columns[1:]:
    print("\n------",column,"-------")
    print(labels_df[column].value_counts())
# Out:
# ------ NewsGuard, Does not repeatedly publish false content -------
# 0.0    68
# 1.0    17
# Name: NewsGuard, Does not repeatedly publish false content, dtype: int64
#
# ------ NewsGuard, Gathers and presents information responsibly -------
# 0.0    61
# 1.0    24
# Name: NewsGuard, Gathers and presents information responsibly, dtype: int64
#
# ------ NewsGuard, Regularly corrects or clarifies errors -------
# 0.0    59
# 1.0    26
# Name: NewsGuard, Regularly corrects or clarifies errors, dtype: int64
#
# ------ NewsGuard, Handles the difference between news and opinion responsibly -------
# 0.0    47
# 1.0    38
# Name: NewsGuard, Handles the difference between news and opinion responsibly, dtype: int64
#
# ------ NewsGuard, Avoids deceptive headlines -------
# 0.0    62
# 1.0    23
# Name: NewsGuard, Avoids deceptive headlines, dtype: int64
#
# ------ NewsGuard, Website discloses ownership and financing -------
# 0.0    59
# 1.0    26
# Name: NewsGuard, Website discloses ownership and financing, dtype: int64
#
# ------ NewsGuard, Clearly labels advertising -------
# 0.0    79
# 1.0     4
# 2.0     2
# Name: NewsGuard, Clearly labels advertising, dtype: int64
#
# ------ NewsGuard, Reveals who's in charge, including any possible conflicts of interest -------
# 0.0    64
# 1.0    21
# Name: NewsGuard, Reveals who's in charge, including any possible conflicts of interest, dtype: int64
#
# ------ NewsGuard, Provides information about content creators -------
# 0.0    64
# 1.0    21
# Name: NewsGuard, Provides information about content creators, dtype: int64
#
# ------ NewsGuard, score -------
# 100.0    30
# 87.5     10
# 17.5      4
# 92.5      4
# 82.5      4
# 95.0      3
# 20.0      3
# 12.5      2
# 75.0      2
# 70.0      2
# 25.0      2
# 32.5      2
# 7.5       2
# 69.5      1
# 52.0      1
# 47.5      1
# 34.5      1
# 57.0      1
# 67.5      1
# 77.5      1
# 22.5      1
# 54.5      1
# 15.0      1
# 29.5      1
# 80.0      1
# 40.0      1
# 42.0      1
# 90.0      1
# Name: NewsGuard, score, dtype: int64
#
# ------ NewsGuard, overall_class -------
# 1.0    60
# 0.0    25
# Name: NewsGuard, overall_class, dtype: int64
#
# ------ Pew Research Center, known_by_40% -------
# 1.0    16
# 0.0     9
# Name: Pew Research Center, known_by_40%, dtype: int64
#
# ------ Pew Research Center, total -------
#  1.0    16
#  0.0     6
# -1.0     3
# Name: Pew Research Center, total, dtype: int64
#
# ------ Pew Research Center, consistently_liberal -------
#  1.0    20
# -1.0     5
# Name: Pew Research Center, consistently_liberal, dtype: int64
#
# ------ Pew Research Center, mostly_liberal -------
#  1.0    17
# -1.0     5
#  0.0     3
# Name: Pew Research Center, mostly_liberal, dtype: int64
#
# ------ Pew Research Center, mixed -------
#  1.0    12
#  0.0    10
# -1.0     3
# Name: Pew Research Center, mixed, dtype: int64
#
# ------ Pew Research Center, mostly conservative -------
# -1.0    12
#  1.0     7
#  0.0     6
# Name: Pew Research Center, mostly conservative, dtype: int64
#
# ------ Pew Research Center, consistently conservative -------
# -1.0    19
#  1.0     4
#  0.0     2
# Name: Pew Research Center, consistently conservative, dtype: int64
#
# ------ Wikipedia, is_fake -------
# 1.0    5
# Name: Wikipedia, is_fake, dtype: int64
#
# ------ Open Sources, reliable -------
# 2.0    3
# Name: Open Sources, reliable, dtype: int64
#
# ------ Open Sources, fake -------
# 1.0    5
# 3.0    1
# Name: Open Sources, fake, dtype: int64
#
# ------ Open Sources, unreliable -------
# 2.0    9
# 1.0    4
# 3.0    2
# Name: Open Sources, unreliable, dtype: int64
#
# ------ Open Sources, bias -------
# 1.0    14
# 2.0     7
# 3.0     4
# Name: Open Sources, bias, dtype: int64
#
# ------ Open Sources, conspiracy -------
# 1.0    11
# 2.0     3
# 3.0     2
# Name: Open Sources, conspiracy, dtype: int64
#
# ------ Open Sources, hate -------
# 2.0    1
# 1.0    1
# Name: Open Sources, hate, dtype: int64
#
# ------ Open Sources, junksci -------
# 1.0    2
# 2.0    1
# Name: Open Sources, junksci, dtype: int64
#
# ------ Open Sources, rumor -------
# 1.0    1
# 2.0    1
# Name: Open Sources, rumor, dtype: int64
#
# ------ Open Sources, blog -------
# Series([], Name: Open Sources, blog, dtype: int64)
#
# ------ Open Sources, clickbait -------
# 2.0    10
# 1.0     4
# Name: Open Sources, clickbait, dtype: int64
#
# ------ Open Sources, political -------
# 1.0    17
# 2.0     1
# 3.0     1
# Name: Open Sources, political, dtype: int64
#
# ------ Open Sources, satire -------
# 1.0    11
# 2.0     2
# Name: Open Sources, satire, dtype: int64
#
# ------ Open Sources, state -------
# 2.0    1
# 1.0    1
# Name: Open Sources, state, dtype: int64
#
# ------ Media Bias / Fact Check, label -------
# left_center_bias            36
# left_bias                   30
# conspiracy_pseudoscience    17
# right_bias                  16
# questionable_source         15
# right_center_bias           10
# satire                       8
# least_biased                 3
# Name: Media Bias / Fact Check, label, dtype: int64
#
# ------ Media Bias / Fact Check, factual_reporting -------
# 4.0    54
# 3.0    48
# 2.0     7
# 5.0     2
# 1.0     1
# Name: Media Bias / Fact Check, factual_reporting, dtype: int64
#
# ------ Media Bias / Fact Check, extreme_left -------
# 0.0    133
# 1.0      2
# Name: Media Bias / Fact Check, extreme_left, dtype: int64
#
# ------ Media Bias / Fact Check, right -------
# 0.0    134
# 1.0      1
# Name: Media Bias / Fact Check, right, dtype: int64
#
# ------ Media Bias / Fact Check, extreme_right -------
# 0.0    123
# 1.0     12
# Name: Media Bias / Fact Check, extreme_right, dtype: int64
#
# ------ Media Bias / Fact Check, propaganda -------
# 0.0    122
# 1.0     13
# Name: Media Bias / Fact Check, propaganda, dtype: int64
#
# ------ Media Bias / Fact Check, fake_news -------
# 0.0    135
# Name: Media Bias / Fact Check, fake_news, dtype: int64
#
# ------ Media Bias / Fact Check, some_fake_news -------
# 0.0    131
# 1.0      4
# Name: Media Bias / Fact Check, some_fake_news, dtype: int64
#
# ------ Media Bias / Fact Check, failed_fact_checks -------
# 0.0    134
# 1.0      1
# Name: Media Bias / Fact Check, failed_fact_checks, dtype: int64
#
# ------ Media Bias / Fact Check, conspiracy -------
# 0.0    126
# 1.0      9
# Name: Media Bias / Fact Check, conspiracy, dtype: int64
#
# ------ Media Bias / Fact Check, pseudoscience -------
# 0.0    134
# 1.0      1
# Name: Media Bias / Fact Check, pseudoscience, dtype: int64
#
# ------ Media Bias / Fact Check, hate_group -------
# 0.0    133
# 1.0      2
# Name: Media Bias / Fact Check, hate_group, dtype: int64
#
# ------ Media Bias / Fact Check, anti_islam -------
# 0.0    134
# 1.0      1
# Name: Media Bias / Fact Check, anti_islam, dtype: int64
#
# ------ Media Bias / Fact Check, nationalism -------
# 0.0    134
# 1.0      1
# Name: Media Bias / Fact Check, nationalism, dtype: int64
#
# ------ Allsides, bias_rating -------
# Left          17
# Right         14
# Lean Left     13
# Center        11
# Lean Right    10
# Name: Allsides, bias_rating, dtype: int64
#
# ------ Allsides, community_agree -------
# 1806.0     2
# 4503.0     1
# 399.0      1
# 4427.0     1
# 2083.0     1
#           ..
# 4434.0     1
# 5463.0     1
# 3579.0     1
# 10753.0    1
# 8964.0     1
# Name: Allsides, community_agree, Length: 64, dtype: int64
#
# ------ Allsides, community_disagree -------
# 18254.0    1
# 24137.0    1
# 116.0      1
# 213.0      1
# 238.0      1
#           ..
# 3158.0     1
# 3857.0     1
# 1665.0     1
# 12981.0    1
# 3249.0     1
# Name: Allsides, community_disagree, Length: 65, dtype: int64
#
# ------ Allsides, community_label -------
# somewhat agree       21
# agree                12
# somewhat disagree    11
# strongly agree       11
# absolutely agree      5
# disagree              3
# strongly disagree     1
# Name: Allsides, community_label, dtype: int64
#
# ------ BuzzFeed, leaning -------
# right    32
# left     24
# Name: BuzzFeed, leaning, dtype: int64
#
# ------ PolitiFact, Pants on Fire! -------
# 0.0    14
# 1.0     6
# 2.0     3
# Name: PolitiFact, Pants on Fire!, dtype: int64
#
# ------ PolitiFact, False -------
# 0.0    15
# 1.0     5
# 2.0     3
# Name: PolitiFact, False, dtype: int64
#
# ------ PolitiFact, Mostly False -------
# 0.0    17
# 1.0     6
# Name: PolitiFact, Mostly False, dtype: int64
#
# ------ PolitiFact, Half-True -------
# 0.0    19
# 1.0     4
# Name: PolitiFact, Half-True, dtype: int64
#
# ------ PolitiFact, Mostly True -------
# 0.0    20
# 1.0     3
# Name: PolitiFact, Mostly True, dtype: int64
#
# ------ PolitiFact, True -------
# 0.0    21
# 1.0     2
# Name: PolitiFact, True, dtype: int64

# %% [markdown]
# # Pew Research Center

# %%
prc_df = util.nela_labels_gtsource(labels_df, "Pew Research Center")
print(prc_df.columns)
# Out:
# Index(['Pew Research Center, known_by_40%', 'Pew Research Center, total',
#        'Pew Research Center, consistently_liberal',
#        'Pew Research Center, mostly_liberal', 'Pew Research Center, mixed',
#        'Pew Research Center, mostly conservative',
#        'Pew Research Center, consistently conservative'],
#       dtype='object')

# %% [markdown]
# ## NewsGuard

# %%
newsguard_df = util.nela_labels_gtsource(labels_df, "NewsGuard")
print(newsguard_df.columns)
# Out:
# Index(['NewsGuard, Does not repeatedly publish false content',
#        'NewsGuard, Gathers and presents information responsibly',
#        'NewsGuard, Regularly corrects or clarifies errors',
#        'NewsGuard, Handles the difference between news and opinion responsibly',
#        'NewsGuard, Avoids deceptive headlines',
#        'NewsGuard, Website discloses ownership and financing',
#        'NewsGuard, Clearly labels advertising',
#        'NewsGuard, Reveals who's in charge, including any possible conflicts of interest',
#        'NewsGuard, Provides information about content creators',
#        'NewsGuard, score', 'NewsGuard, overall_class'],
#       dtype='object')

# %%
newsguard_df
# Out:
#      NewsGuard, Does not repeatedly publish false content  \
# 0                                                  NaN
# 1                                                  0.0
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 189                                                NaN
# 190                                                NaN
# 191                                                NaN
# 192                                                NaN
# 193                                                NaN
#
#      NewsGuard, Gathers and presents information responsibly  \
# 0                                                  NaN
# 1                                                  0.0
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 189                                                NaN
# 190                                                NaN
# 191                                                NaN
# 192                                                NaN
# 193                                                NaN
#
#      NewsGuard, Regularly corrects or clarifies errors  \
# 0                                                  NaN
# 1                                                  0.0
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 189                                                NaN
# 190                                                NaN
# 191                                                NaN
# 192                                                NaN
# 193                                                NaN
#
#      NewsGuard, Handles the difference between news and opinion responsibly  \
# 0                                                  NaN
# 1                                                  0.0
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 189                                                NaN
# 190                                                NaN
# 191                                                NaN
# 192                                                NaN
# 193                                                NaN
#
#      NewsGuard, Avoids deceptive headlines  \
# 0                                      NaN
# 1                                      0.0
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# ..                                     ...
# 189                                    NaN
# 190                                    NaN
# 191                                    NaN
# 192                                    NaN
# 193                                    NaN
#
#      NewsGuard, Website discloses ownership and financing  \
# 0                                                  NaN
# 1                                                  0.0
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 189                                                NaN
# 190                                                NaN
# 191                                                NaN
# 192                                                NaN
# 193                                                NaN
#
#      NewsGuard, Clearly labels advertising  \
# 0                                      NaN
# 1                                      0.0
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# ..                                     ...
# 189                                    NaN
# 190                                    NaN
# 191                                    NaN
# 192                                    NaN
# 193                                    NaN
#
#      NewsGuard, Reveals who's in charge, including any possible conflicts of interest  \
# 0                                                  NaN
# 1                                                  1.0
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 189                                                NaN
# 190                                                NaN
# 191                                                NaN
# 192                                                NaN
# 193                                                NaN
#
#      NewsGuard, Provides information about content creators  NewsGuard, score  \
# 0                                                  NaN                    NaN
# 1                                                  0.0                   95.0
# 2                                                  NaN                    NaN
# 3                                                  NaN                    NaN
# 4                                                  NaN                    NaN
# ..                                                 ...                    ...
# 189                                                NaN                    NaN
# 190                                                NaN                    NaN
# 191                                                NaN                    NaN
# 192                                                NaN                    NaN
# 193                                                NaN                    NaN
#
#      NewsGuard, overall_class
# 0                         NaN
# 1                         1.0
# 2                         NaN
# 3                         NaN
# 4                         NaN
# ..                        ...
# 189                       NaN
# 190                       NaN
# 191                       NaN
# 192                       NaN
# 193                       NaN
#
# [194 rows x 11 columns]

# %% [markdown]
# ## Open Sources

# %%
opensources_df = util.nela_labels_gtsource(labels_df, "Open Sources")
print(opensources_df.columns)
# Out:
# Index(['Open Sources, reliable', 'Open Sources, fake',
#        'Open Sources, unreliable', 'Open Sources, bias',
#        'Open Sources, conspiracy', 'Open Sources, hate',
#        'Open Sources, junksci', 'Open Sources, rumor', 'Open Sources, blog',
#        'Open Sources, clickbait', 'Open Sources, political',
#        'Open Sources, satire', 'Open Sources, state'],
#       dtype='object')

# %%
opensources_df["Open Sources, reliable"].value_counts()
# Out:
# 2.0    3
# Name: Open Sources, reliable, dtype: int64

# %%
opensources_df["Open Sources, fake"].value_counts()
# Out:
# 1.0    5
# 3.0    1
# Name: Open Sources, fake, dtype: int64

# %%
opensources_df["Open Sources, unreliable"].value_counts()
# Out:
# 2.0    9
# 1.0    4
# 3.0    2
# Name: Open Sources, unreliable, dtype: int64

# %%
opensources_df["Open Sources, bias"].value_counts()
# Out:
# 1.0    14
# 2.0     7
# 3.0     4
# Name: Open Sources, bias, dtype: int64

# %%
#with pd.option_context('display.max_rows', None, 'display.max_columns', None):  # more options can be specified also
#    display(opensources_df)

# %% [markdown]
# ## Media Bias

# %%
mediabias_df = util.nela_labels_gtsource(labels_df, "Media Bias / Fact Check")
print(mediabias_df.columns)
# Out:
# Index(['Media Bias / Fact Check, label',
#        'Media Bias / Fact Check, factual_reporting',
#        'Media Bias / Fact Check, extreme_left',
#        'Media Bias / Fact Check, right',
#        'Media Bias / Fact Check, extreme_right',
#        'Media Bias / Fact Check, propaganda',
#        'Media Bias / Fact Check, fake_news',
#        'Media Bias / Fact Check, some_fake_news',
#        'Media Bias / Fact Check, failed_fact_checks',
#        'Media Bias / Fact Check, conspiracy',
#        'Media Bias / Fact Check, pseudoscience',
#        'Media Bias / Fact Check, hate_group',
#        'Media Bias / Fact Check, anti_islam',
#        'Media Bias / Fact Check, nationalism'],
#       dtype='object')

# %%
mediabias_df["Media Bias / Fact Check, label"].value_counts()
# Out:
# left_center_bias            36
# left_bias                   30
# conspiracy_pseudoscience    17
# right_bias                  16
# questionable_source         15
# right_center_bias           10
# satire                       8
# least_biased                 3
# Name: Media Bias / Fact Check, label, dtype: int64

# %% [markdown]
# ## Allsides

# %%
allsides_df = util.nela_labels_gtsource(labels_df, "Allsides")
print(allsides_df.columns)

allsides_df["Allsides, bias_rating"].value_counts()
# Out:
# Index(['Allsides, bias_rating', 'Allsides, community_agree',
#        'Allsides, community_disagree', 'Allsides, community_label'],
#       dtype='object')
# Left          17
# Right         14
# Lean Left     13
# Center        11
# Lean Right    10
# Name: Allsides, bias_rating, dtype: int64

# %%
total = 0
for count in allsides_df["Allsides, bias_rating"].value_counts():
    total += count
print(total)
# Out:
# 65

# %%
allsides_df
# Out:
#     Allsides, bias_rating  Allsides, community_agree  \
# 0                     NaN                        NaN
# 1               Lean Left                     8964.0
# 2                     NaN                        NaN
# 3                     NaN                        NaN
# 4                     NaN                        NaN
# ..                    ...                        ...
# 189                   NaN                        NaN
# 190                   NaN                        NaN
# 191                   NaN                        NaN
# 192                   NaN                        NaN
# 193                   NaN                        NaN
#
#      Allsides, community_disagree Allsides, community_label
# 0                             NaN                       NaN
# 1                          6949.0            somewhat agree
# 2                             NaN                       NaN
# 3                             NaN                       NaN
# 4                             NaN                       NaN
# ..                            ...                       ...
# 189                           NaN                       NaN
# 190                           NaN                       NaN
# 191                           NaN                       NaN
# 192                           NaN                       NaN
# 193                           NaN                       NaN
#
# [194 rows x 4 columns]

# %%
allsides_df["Allsides, bias_rating"].value_counts()
# Out:
# Left          17
# Right         14
# Lean Left     13
# Center        11
# Lean Right    10
# Name: Allsides, bias_rating, dtype: int64

# %% [markdown]
# ## Buzzfeed

# %%
buzzfeed_df = util.nela_labels_gtsource(labels_df, "BuzzFeed")
print(buzzfeed_df.columns)
# Out:
# Index(['BuzzFeed, leaning'], dtype='object')

# %%
buzzfeed_df["BuzzFeed, leaning"].value_counts()
# Out:
# right    32
# left     24
# Name: BuzzFeed, leaning, dtype: int64

# %% [markdown]
# Note that this doesn't have every source, so any not contained could be assumed to not be biased? (no, probably not correct)

# %% [markdown]
# # NELA-GT-2018 (dataset description from README.md)
#
# ## Dataset Articles
#
# The articles gathered in this dataset is found in an sqlite database. The database has one table name `articles`. This table has 4 textual columns:
#
# 1. `date`: Date of article in `yyyy-mm-dd` format.
# 1. `source`: Source of article.
# 1. `name`: Title of article.
# 1. `content`: Clean text content of article.
#
# The rows of the article are sorted first with respect to `date` and then with respect to `source`.
#
# The dataset's articles are also provided in plain-text files, with file-structure and file naming convension:
# ```
# date/
# 	source/
# 		<source>--<date>--<title>.txt
# ```
#
# ## Dataset Labels
#
# The labels of sources are stored in a comma-seperated file *labels.csv* and in a human-readable format in *labels.txt*. Each row in the files contain information about a source.
# The column names use the naming convention `<site_name>,<label_name>`, where `<site_name>` is the name of the site providing the label and `<label_name>` is the name of the particular label. The following lists all columns in the labels files. The columns use different value, which is described below. Note that all columns can also have missing value (no data for that particular source).
#
# 1.  Source names
#   	**NewsGuard labels:**
# 1. NewsGuard, Does not repeatedly publish false content `1 true, 0 false`
# 2. NewsGuard, Gathers and presents information responsibly `1 true, 0 false`
# 3. NewsGuard, Regularly corrects or clarifies errors `1 true, 0 false`
# 4. NewsGuard, Handles the difference between news and opinion responsibly `1 true, 0 false`
# 5. NewsGuard, Avoids deceptive headlines `1 true, 0 false`
# 6. NewsGuard, Website discloses ownership and financing `1 true, 0 false`
# 7. NewsGuard, Clearly labels advertising `1 true, 0 false`
# 8. NewsGuard, Reveals who's in charge, including any possible conflicts of interest `1 true, 0 false`
# 9. NewsGuard, Provides information about content creators `1 true, 0 false`
# 10. NewsGuard, score `0-100`
# 11. NewsGuard, overall_class `1 good, 0 bad`
# 	**Pew Research Center**
# 12. Pew Research Center, known_by_40% `1 true, 0 false`
# 13. Pew Research Center, total `1 trusted, 0 undecided, -1 not trusted`
# 14. Pew Research Center, consistently_liberal `1 trusted, 0 undecided, -1 not trusted`
# 15. Pew Research Center, mostly_liberal `1 trusted, 0 undecided, -1 not trusted`
# 16. Pew Research Center, mixed `1 trusted, 0 undecided, -1 not trusted`
# 17. Pew Research Center, mostly conservative `1 trusted, 0 undecided, -1 not trusted`
# 18. Pew Research Center, consistently conservative `1 trusted, 0 undecided, -1 not trusted`
# 	**Wikipedia**
# 19. Wikipedia, is_fake `1 marked`
# 	**Open Sources**
# 20. Open Sources, reliable `# tag`
# 21. Open Sources, fake `# tag`
# 22. Open Sources, unreliable `# tag`
# 23. Open Sources, bias `# tag`
# 24. Open Sources, conspiracy `# tag`
# 25. Open Sources, hate `# tag`
# 26. Open Sources, junksci `# tag`
# 27. Open Sources, rumor `# tag`
# 28. Open Sources, blog `# tag`
# 29. Open Sources, clickbait `# tag`
# 30. Open Sources, political `# tag`
# 31. Open Sources, satire `# tag`
# 32. Open Sources, state `# tag`
# 	**Media Bias / Fact Check**
# 33. Media Bias / Fact Check, label `label`
# 34. Media Bias / Fact Check, factual_reporting `bad 1 - 5 good`
# 35. Media Bias / Fact Check, extreme_left `1 true, 0 false`
# 36. Media Bias / Fact Check, right `1 true, 0 false`
# 37. Media Bias / Fact Check, extreme_right `1 true, 0 false`
# 38. Media Bias / Fact Check, propaganda `1 true, 0 false`
# 39. Media Bias / Fact Check, fake_news `1 true, 0 false`
# 40. Media Bias / Fact Check, some_fake_news `1 true, 0 false`
# 41. Media Bias / Fact Check, failed_fact_checks `1 true, 0 false`
# 42. Media Bias / Fact Check, conspiracy `1 true, 0 false`
# 43. Media Bias / Fact Check, pseudoscience `1 true, 0 false`
# 44. Media Bias / Fact Check, hate_group `1 true, 0 false`
# 45. Media Bias / Fact Check, anti_islam `1 true, 0 false`
# 46. Media Bias / Fact Check, nationalism `1 true, 0 false`
# 	**Allsides**
# 47. Allsides, bias_rating `rating label`
# 48. Allsides, community_agree `# votes agreeing`
# 49. Allsides, community_disagree `# votes disagreeing`
# 50. Allsides, community_label `agreement label`
# 	**BuzzFeed**
# 51. BuzzFeed, leaning `left, right`
# 	**Politifact**
# 52. PolitiFact, Pants on Fire! `# counts`
# 53. PolitiFact, False `# counts`
# 54. PolitiFact, Mostly False `# counts`
# 55. PolitiFact, Half-True `# counts`
# 56. PolitiFact, Mostly True `# counts`
# 57. PolitiFact, True `# counts`
